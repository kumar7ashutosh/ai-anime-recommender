# %%
import os

# %%
df={
    "MAIL_ID":["A","B","C"],
    "Name":["A","B","C"],
    "Score":["A","B","C"],
    "Genres":["A","B","C"],
    "sypnosis":["A","B","C"]
}

# %%
import pandas as pd

# %%
df=pd.DataFrame(df)

# %%
df.columns
# Out:
# Index(['MAIL_ID', 'Name', 'Score', 'Genres', 'sypnosis'], dtype='str')

# %%
req_cols={'Name','Genres','sypnosis'}

# %%
res=req_cols-set(df.columns)

# %%
res
# Out:
# set()

# %%
if set(df.columns) not in req_cols:
    print("missed")
else:
    print("it's okay")
# Out:
# missed

# %%
res=set(df.columns)-req_cols

# %%
res
# Out:
# {'MAIL_ID', 'Score'}
